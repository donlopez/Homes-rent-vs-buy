# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("pandas is imported")
# Out:
# C:\Users\welve\AppData\Local\Temp\ipykernel_26224\2582675832.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# pandas is imported

# %% [markdown]
# ## Housing Price Dataset
#
# This dataset contains housing price indices for various regions in the United States, including metropolitan areas, over a span from January 2000 to December 2023. It includes data such as:
#
# - RegionID and SizeRank: Identification and ranking information for the regions.
# - RegionName and StateName: Names of the metropolitan areas and their corresponding states.
# - RegionType: The type of region, such as "msa" (metropolitan statistical area) or "country" for the United States overall.
# - Monthly Price Data: Starting from January 31, 2000, to December 31, 2023, representing the home values at those times.
#
# ## Analysis and Visualization
#
# For the analysis and visualization, we can explore trends in housing prices over time for specific regions or the United States overall. Some potential visualizations include:
#
# 1. Trend Analysis: Plotting the average housing price over time to identify overall market trends.
# 2. Comparative Analysis: Comparing housing price trends between different metropolitan areas.
# 3. Yearly Change Visualization: Analyzing the year-over-year change in housing prices.
#
# Feel
# Trend Analysis: Plotting the average housing price over time to identify overall market trends.
# Comparative Analysis: Comparing housing price trends between different metropolitan areas.
# Yearly Change Visualization: Analyzing the year-over-year change in housing prices.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\welve\Documents\GitHub\Homes-rent-vs-buy\datasets\Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
df
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0      102001         0    United States    country       NaN  118707.067403
# 1      394913         1     New York, NY        msa        NY  214711.957315
# 2      753899         2  Los Angeles, CA        msa        CA  216061.085437
# 3      394463         3      Chicago, IL        msa        IL  148346.569648
# 4      394514         4       Dallas, TX        msa        TX  123115.492393
# ..        ...       ...              ...        ...       ...            ...
# 890    753929       935       Zapata, TX        msa        TX            NaN
# 891    394743       936    Ketchikan, AK        msa        AK            NaN
# 892    753874       937        Craig, CO        msa        CO   94896.399568
# 893    395188       938       Vernon, TX        msa        TX            NaN
# 894    394767       939       Lamesa, TX        msa        TX            NaN
#
# ...

# %%
# Load the data from the newly uploaded file again
file_path_new = r'C:\Users\welve\Documents\GitHub\Homes-rent-vs-buy\datasets\Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv'
data_new = pd.read_csv(file_path_new)

# Display the first few rows of the dataframe to understand its structure
data_new.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName     2000-01-31  \
# 0    102001         0    United States    country       NaN  118707.067403
# 1    394913         1     New York, NY        msa        NY  214711.957315
# 2    753899         2  Los Angeles, CA        msa        CA  216061.085437
# 3    394463         3      Chicago, IL        msa        IL  148346.569648
# 4    394514         4       Dallas, TX        msa        TX  123115.492393
#
#       2000-02-29     2000-03-31     2000-04-30     2000-05-31  ...  \
# 0  118915.911190  119174.908235  119730.406059  120369.717454  ...
# 1  215624.361989  216545.217175  218411.226107  220343.542977  ...
# 2  216865.106811  217936.055612  220066.883970  222397.342176  ...
# 3  148483.895357  148745.434588  149396.079198  150178.726403  ...
# 4  123170.328463  123233.368140  123397.075558  123612.919307  ...
#
#       2023-03-31     2023-04-30     2023-05-31     2023-06-30     2023-07-31  \
# ...

# %% [markdown]
# ## Trending Housing Prices in the United States
#
# For a general trend analysis of housing prices in the United States, we'll focus on the overall trend across the entire time span of the dataset. This will involve:
#
# 1. Extracting the United States data: Isolating the row corresponding to the entire United States.
# 2. Plotting the trend: Visualizing the change in housing prices from January 2000 to December 2023.
#
# Let's proceed with these steps to analyze the trend in housing prices.

# %%
# Extract data for the United States
us_data = data_new[data_new['RegionName'] == 'United States'].iloc[:, 5:]

# Transpose the data to make it easier to plot
us_data_transposed = us_data.T
us_data_transposed.columns = ['Housing Prices']
us_data_transposed.index = pd.to_datetime(us_data_transposed.index)

# Plotting the trend with specified customizations
plt.figure(figsize=(14, 7))
ax = plt.gca()

# Setting background color with gradient
ax.set_facecolor("black")
ax.figure.patch.set_facecolor('grey')
ax.figure.patch.set_alpha(0.5)

# Plotting the data with customized trend line
plt.plot(us_data_transposed.index, us_data_transposed['Housing Prices'], color='yellow', marker='', linestyle='-', linewidth=2.5)

# Customizing the grid, ticks, and labels
plt.grid(color='white', linestyle='--', linewidth=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')

# Customizing the title
plt.title('Trend of Housing Prices in the United States (2000-2023)', color='white')

# Setting the xlabel and ylabel
plt.xlabel('Year')
plt.ylabel('Average Housing Price ($)')

plt.show()

# %% [markdown]
# ## Dataset Overview
#
# I'll first load and examine the contents of the dataset to understand its structure and the type of data it contains. This initial step will guide the subsequent analysis and the choice of visualizations. Let's start by loading the data.
#
# The dataset contains rental price indices for various regions in the United States, including metropolitan areas, from January 2015 to January 2024. It includes the following columns:
#
# - RegionID and SizeRank: Identification and ranking information for the regions.
# - RegionName and StateName: Names of the metropolitan areas and their corresponding states.
# - RegionType: The type of region, such as "msa" (metropolitan statistical area) or "country" for the United States overall.
# - Monthly Rental Data: Starting from January 31, 2015, to January 31, 2024, representing the rental prices at those times.
#
# ## Analysis and Visualization
#
# For the analysis and visualization, we can explore trends in rental prices over time for specific regions or the United States overall. Some potential visualizations include:
#
#
# Trend Analysis: Plotting the average rental price over time to identify overall market trends.
# Comparative Analysis: Comparing rental price trends between different metropolitan areas.
# Yearly Change Visualization: Analyzing the year-over-year change in rental prices.

# %%
# Load the newly uploaded data
rentals_file_path = r'C:\Users\welve\Documents\GitHub\Homes-rent-vs-buy\datasets/Rentals_zori_uc_sfrcondomfr_sm_month.csv'
rentals_data = pd.read_csv(rentals_file_path)

# Display the first few rows of the dataframe to understand its structure
rentals_data.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0    102001         0    United States    country       NaN  1226.804786
# 1    394913         1     New York, NY        msa        NY  2270.423762
# 2    753899         2  Los Angeles, CA        msa        CA  1829.230400
# 3    394463         3      Chicago, IL        msa        IL  1394.075948
# 4    394514         4       Dallas, TX        msa        TX  1114.512597
#
#     2015-02-28   2015-03-31   2015-04-30   2015-05-31  ...   2023-04-30  \
# 0  1233.429814  1242.343254  1252.105321  1261.794962  ...  1922.815353
# 1  2285.734398  2302.828153  2324.396269  2339.849320  ...  3063.255826
# 2  1841.433177  1856.544675  1870.308657  1884.657296  ...  2848.450750
# 3  1401.456452  1411.956007  1421.444960  1432.466113  ...  1882.487607
# 4  1119.853138  1127.778577  1138.707609  1148.859731  ...  1769.217574
#
#     2023-05-31   2023-06-30   2023-07-31   2023-08-31   2023-09-30  \
# ...

# %% [markdown]
# ## General Trend Analysis of Rental Prices in the United States
#
# For the general trend analysis of rental prices in the United States, we'll focus on the overall trend across the entire time span of the dataset. This will involve:
#
# 1. Extracting the United States data: Isolating the row corresponding to the entire United States.
# 2. Plotting the trend: Visualizing the change in rental prices from January 2015 to January 2024.
#
# Let's proceed with these steps to analyze the trend in rental prices.

# %%
# Extract data for the United States
us_rental_data = rentals_data[rentals_data['RegionName'] == 'United States'].iloc[:, 5:]

# Transpose the data to make it easier to plot
us_rental_data_transposed = us_rental_data.T
us_rental_data_transposed.columns = ['Rental Prices']
us_rental_data_transposed.index = pd.to_datetime(us_rental_data_transposed.index)

# Plotting the rental trend with specified customizations
plt.figure(figsize=(14, 7))
ax = plt.gca()

# Setting background color with gradient
ax.set_facecolor("black")
ax.figure.patch.set_facecolor('grey')
ax.figure.patch.set_alpha(0.5)

# Plotting the data with customized trend line
plt.plot(us_rental_data_transposed.index, us_rental_data_transposed['Rental Prices'], color='yellow', marker='', linestyle='-', linewidth=2.5)

# Customizing the grid, ticks, and labels
plt.grid(color='white', linestyle='--', linewidth=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')

# Customizing the title
plt.title('Trend of Rental Prices in the United States (2015-2024)', color='white')

# Setting the xlabel and ylabel
plt.xlabel('Year')
plt.ylabel('Average Rental Price ($)')

plt.show()

# %% [markdown]
# ## Trend of Rental Prices in the United States (January 2015 - January 2024)
#
# The trend of rental prices in the United States from January 2015 to January 2024 shows a clear overall increase, with variations that reflect the dynamics of the rental market over the past 9 years. Here are some key observations from the plot:
#
# - Steady Growth: Rental prices have generally been on an upward trend, indicating a long-term increase in rental costs across the United States.
# - Periodic Fluctuations: There are periods of faster growth as well as periods where the growth rate seems to stabilize or slightly decline, which may correspond to economic factors, housing market conditions, and changes in supply and demand.
# - Recent Trends: The plot shows a continuation of growth in rental prices, reaching their highest levels towards the end of the dataset in January 2024.
#
# This visualization helps to understand the overall behavior of the rental market in the United States over the observed period, highlighting the long-term increase in rental costs despite short-term fluctuations.

# %% [markdown]
# ## Comparing Percentage Changes in Housing and Rental Prices
#
# To compare the percentage changes in both housing prices and rental prices in the United States, we'll follow these steps:
#
# 1. Calculate Percentage Changes: We'll calculate the percentage changes for both datasets to standardize the comparison, focusing on the overall United States data.
# 2. Align Time Frames: If necessary, we'll align the time frames to ensure we compare the same periods across both datasets.
# 3. Create a Combined Visualization: We'll create a combined visualization that shows the percentage changes over time for both housing and rental prices on the same chart.
#
# Let's start by calculating the percentage changes for both housing and rental prices.

# %%
# Calculate percentage change for housing prices
us_housing_prices = data_new[data_new['RegionName'] == 'United States'].iloc[:, 5:].T
us_housing_prices.columns = ['Housing Prices']
us_housing_prices.index = pd.to_datetime(us_housing_prices.index)
housing_pct_change = us_housing_prices.pct_change().dropna()

# Calculate percentage change for rental prices
us_rental_prices = rentals_data[rentals_data['RegionName'] == 'United States'].iloc[:, 5:].T
us_rental_prices.columns = ['Rental Prices']
us_rental_prices.index = pd.to_datetime(us_rental_prices.index)
rental_pct_change = us_rental_prices.pct_change().dropna()

# Since the datasets may cover different time spans, we align them by their common dates
common_dates = housing_pct_change.index.intersection(rental_pct_change.index)
housing_pct_change_aligned = housing_pct_change.loc[common_dates]
rental_pct_change_aligned = rental_pct_change.loc[common_dates]

# Plotting the percentage changes with specified customizations
plt.figure(figsize=(14, 7))
ax = plt.gca()

# Setting background color with gradient
ax.set_facecolor("black")
ax.figure.patch.set_facecolor('grey')
ax.figure.patch.set_alpha(0.5)

# Plotting the data with customized trend lines
plt.plot(housing_pct_change_aligned.index, housing_pct_change_aligned['Housing Prices'] * 100, label='Housing Price Change (%)', color='blue', linewidth=2.5)
plt.plot(rental_pct_change_aligned.index, rental_pct_change_aligned['Rental Prices'] * 100, label='Rental Price Change (%)', color='yellow', linewidth=2.5)

# Customizing the grid, ticks, and labels
plt.grid(color='white', linestyle='--', linewidth=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')

# Customizing the title and legend
plt.title('Percentage Change in Housing vs. Rental Prices in the United States', color='white')
plt.xlabel('Year')
plt.ylabel('Percentage Change (%)')
plt.legend()

plt.show()

# %% [markdown]
# ## Comparative Analysis: Percentage Change in Housing vs. Rental Prices
#
# The chart visualizes the percentage change in housing versus rental prices in the United States, with both datasets aligned to their common dates. Here are some insights from the visualization:
#
# - **Comparative Trends:** Both housing and rental prices show fluctuations over time, but the percentage changes highlight how these two markets move in relation to each other.
# - **Volatility:** The percentage changes indicate periods of increased volatility, where significant increases or decreases in prices occurred within a short time frame.
# - **Cyclical Patterns:** There appears to be a cyclical pattern in both markets, with periods of growth followed by stabilization or decline, reflecting broader economic conditions and market dynamics.
#
# This comparison provides a clear view of how the housing and rental markets have evolved in tandem, offering insights into the interplay between buying and renting in the United States.
